# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# scaling
from sklearn.preprocessing import StandardScaler

# %%
# 데이터 소수점 지정
pd.options.display.precision = 2

# 한글 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'AppleGothic'
# plt.rcParams['font.family'] = 'Malgun Gothic'




# 불필요한 경고 메시지를 나오지 않도록 한다.
import warnings
warnings.filterwarnings('ignore')

# %%
df_raw = pd.read_csv('add_variable_customer.csv', encoding='euc-kr')

# %%
df_raw.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
df_raw
# Out:
#      CustomerId Gender  Age  AgeGroup Married Dependents  noDependents  \
# 0       C-10001     여성   37        30     Yes         No             0
# 1       C-10002     남성   46        40      No         No             0
# 2       C-10003     남성   50        50      No         No             0
# 3       C-10004     남성   78        70     Yes         No             0
# 4       C-10005     여성   75        70     Yes         No             0
# ...         ...    ...  ...       ...     ...        ...           ...
# 6858    C-17039     여성   20        20      No         No             0
# 6859    C-17040     남성   40        40     Yes         No             0
# 6860    C-17041     남성   22        20      No         No             0
# 6861    C-17042     남성   21        20      No         No             0
# 6862    C-17043     남성   36        30     Yes         No             0
#
#      Referrals  noReferrals PaperlessBilling  ... SatisScore  \
# 0          Yes            2              Yes  ...          3
# 1           No            0               No  ...          5
# 2           No            0              Yes  ...          1
# 3          Yes            1              Yes  ...          1
# 4          Yes            3              Yes  ...          1
# ...        ...          ...              ...  ...        ...
# 6858        No            0               No  ...          4
# 6859       Yes            1              Yes  ...          1
# 6860        No            0              Yes  ...          5
# 6861       Yes            5               No  ...          3
# 6862       Yes            1               No  ...          3
#
#      TotalExtraDataCharge AvgRoamCharge TotalRoamCharge TenureMonths  \
# 0                       0         47910          431100           21
# 1                   11300         12090          108710           21
# 2                       0         38080          152100            4
# 3                       0         31410          408720           13
# 4                       0          8360           24970            3
# ...                   ...           ...             ...          ...
# 6858                    0         52770          685680           25
# 6859                    0         18310          402730           22
# 6860                    0         21020           42040           14
# 6861                    0          2370          160460           79
# 6862                    0             0               0           75
#
#       AvgCharge TotalCharge TotalRevenue MonthRoamCharge  AvgExtraDataCharge
# 0      83590.48     1755400      2186500           20528                   0
# 1      68928.57     1447500      1567510            5176                 538
# 2      98180.00      490900       643000           38025                   0
# 3     112742.86     1578400      1987120           31440                   0
# 4      94500.00      378000       402970            8323                   0
# ...         ...         ...          ...             ...                 ...
# 6858   64428.00     1610700      2296380           27427                   0
# 6859  101891.30     2343500      2746230           18305                   0
# 6860   56600.00      792400       834440            3002                   0
# 6861   80107.59     6328500      6488960            2031                   0
# 6862   69281.33     5196100      5196100               0                   0
#
# [6863 rows x 34 columns]

# %% [markdown]
# ##### @Gender : 여성(1), 남성(0)

# %%
df_raw['Gender'] = df_raw['Gender'].replace(to_replace='여성', value=1)
df_raw['Gender'] = df_raw['Gender'].replace(to_replace='남성', value=0)

# %% [markdown]
# ##### @Married : Yes(1), No(0)

# %%
df_raw['Married'] = df_raw['Married'].replace(to_replace='Yes', value=1)
df_raw['Married'] = df_raw['Married'].replace(to_replace='No', value=0)

# %% [markdown]
# ##### @Referrals : Yes(1), No(0)

# %%
df_raw['Referrals'] = df_raw['Referrals'].replace(to_replace='Yes', value=1)
df_raw['Referrals'] = df_raw['Referrals'].replace(to_replace='No', value=0)

# %% [markdown]
# ##### @Dependents: Yes(1), No(0)

# %%
df_raw['Dependents'] = df_raw['Dependents'].replace(to_replace='Yes', value=1)
df_raw['Dependents'] = df_raw['Dependents'].replace(to_replace='No', value=0)

# %% [markdown]
# ##### @PaperlessBilling  : Yes(1), No(0)

# %%
df_raw['PaperlessBilling'] = df_raw['PaperlessBilling'].replace(to_replace='Yes', value=1)
df_raw['PaperlessBilling'] = df_raw['PaperlessBilling'].replace(to_replace='No', value=0)

# %% [markdown]
# ##### @PaymentMethod

# %%
df_raw['PaymentMethod'] = df_raw['PaymentMethod'].replace(to_replace='신용카드', value=1)
df_raw['PaymentMethod'] = df_raw['PaymentMethod'].replace(to_replace='계좌이체', value=0)
df_raw['PaymentMethod'] = df_raw['PaymentMethod'].replace(to_replace='이체/메일확인', value=2)

# %% [markdown]
# ##### @OnlineSecurity

# %%
df_raw['OnlineSecurity'] = df_raw['OnlineSecurity'].replace(to_replace='Yes', value=1)
df_raw['OnlineSecurity'] = df_raw['OnlineSecurity'].replace(to_replace='No', value=0)

# %% [markdown]
# ##### @OnlineBackup  : Yes(1), No(0)

# %%
df_raw['OnlineBackup'] = df_raw['OnlineBackup'].replace(to_replace='Yes', value=1)
df_raw['OnlineBackup'] = df_raw['OnlineBackup'].replace(to_replace='No', value=0)

# %% [markdown]
# ##### @TechSupport  : Yes(1), No(0)

# %%
df_raw['TechSupport'] = df_raw['TechSupport'].replace(to_replace='Yes', value=1)
df_raw['TechSupport'] = df_raw['TechSupport'].replace(to_replace='No', value=0)

# %% [markdown]
# ##### @UnlimitedData : Yes(1), No(0)

# %%
df_raw['UnlimitedData'] = df_raw['UnlimitedData'].replace(to_replace='Yes', value=1)
df_raw['UnlimitedData'] = df_raw['UnlimitedData'].replace(to_replace='No', value=0)

# %% [markdown]
# # DT

# %%
# export_graphviz: 나무 구조 생성 및 저장 
from sklearn.tree import export_graphviz
# graphviz : 나무 구조 시각화  (.dot 확장자 파일 불러오기 등)
import graphviz

# 데이터 분할:train, test
from sklearn.model_selection import train_test_split
# 분류 Decision Tree
from sklearn.tree import DecisionTreeClassifier
# 최적 모델, 파라미터 탐색
from sklearn.model_selection import GridSearchCV

# 분류모델 평가 함수
from sklearn.metrics import accuracy_score, f1_score 
from sklearn.metrics import confusion_matrix, classification_report

# %%
df_raw.drop(['CustomerId', 'StartDate', 'EndDate',
             'EndDateTmp', 'ChurnCategory', 'ChurnReason'], axis=1, inplace=True)

# %%
# df_raw.drop('CustomerLTV', axis=1, inplace=True)

# %% [markdown]
# ## 데이터 분할

# %%
# 설명변수, 목표변수 데이터 구분
df_raw_x = df_raw.drop('ChurnLabel', axis=1, inplace=False)
df_raw_y = df_raw['ChurnLabel']


df_train_x, df_test_x, df_train_y, df_test_y = train_test_split(df_raw_x, df_raw_y,
                                                               test_size=0.3, random_state=42)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6863 entries, 0 to 6862
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                6863 non-null   int64
#  1   Age                   6863 non-null   int64
#  2   AgeGroup              6863 non-null   int64
#  3   Married               6863 non-null   int64
#  4   Dependents            6863 non-null   int64
#  5   noDependents          6863 non-null   int64
#  6   Referrals             6863 non-null   int64
#  7   noReferrals           6863 non-null   int64
#  8   PaperlessBilling      6863 non-null   int64
#  9   PaymentMethod         6863 non-null   int64
#  10  OnlineSecurity        6863 non-null   int64
#  11  OnlineBackup          6863 non-null   int64
#  12  TechSupport           6863 non-null   int64
#  13  UnlimitedData         6863 non-null   int64
#  14  AvgDownloadGB         6863 non-null   int64
#  15  ChurnLabel            6863 non-null   int64
#  16  ChurnScore            6863 non-null   int64
#  17  CustomerLTV           6863 non-null   int64
#  18  SatisScore            6863 non-null   int64
#  19  TotalExtraDataCharge  6863 non-null   int64
#  20  AvgRoamCharge         6863 non-null   int64
#  21  TotalRoamCharge       6863 non-null   int64
#  22  TenureMonths          6863 non-null   int64
#  23  AvgCharge             6863 non-null   float64
#  24  TotalCharge           6863 non-null   int64
#  25  TotalRevenue          6863 non-null   int64
#  26  MonthRoamCharge       6863 non-null   int64
#  27  AvgExtraDataCharge    6863 non-null   int64
# dtypes: float64(1), int64(27)
# memory usage: 1.5 MB

# %%
print('분할 전 설명변수 데이터: ', df_raw_x.shape)
print('분할 후 설명변수 데이터 \ntrain : ', df_train_x.shape, ' test: ', df_test_x.shape)
# Out:
# 분할 전 설명변수 데이터:  (6863, 27)
# 분할 후 설명변수 데이터
# train :  (4804, 27)  test:  (2059, 27)

# %%
tree_uncustomized = DecisionTreeClassifier(random_state=42 )
tree_uncustomized.fit(df_train_x, df_train_y)

# train 데이터 정확도
print("Accuracy on training set: {:.3f}".format(tree_uncustomized.score(df_train_x, df_train_y)))
# test 데이터 정확도å
print("Accuracy on test set: {:.3f}".format(tree_uncustomized.score(df_test_x, df_test_y)))
# Out:
# Accuracy on training set: 1.000
# Accuracy on test set: 0.989

# %%
v_feature_name = df_train_x.columns

# %%
# tree.feature_importances_로 설명변수 중요도 확인 및 테이블로 저장
df_importance = pd.DataFrame()
df_importance["Feature"] = v_feature_name
df_importance["Importance"] = tree_uncustomized.feature_importances_

# df_feature_importance의 테이블을 중요도별로 정렬
df_importance.sort_values("Importance", ascending=False, inplace = True)
df_importance.round(3)
# Out:
#                  Feature  Importance
# 17            SatisScore    7.20e-01
# 21          TenureMonths    1.58e-01
# 15            ChurnScore    6.80e-02
# 25       MonthRoamCharge    1.80e-02
# 22             AvgCharge    1.00e-02
# 19         AvgRoamCharge    8.00e-03
# 16           CustomerLTV    5.00e-03
# 10        OnlineSecurity    4.00e-03
# 24          TotalRevenue    2.00e-03
# 7            noReferrals    2.00e-03
# 5           noDependents    2.00e-03
# 14         AvgDownloadGB    1.00e-03
# 26    AvgExtraDataCharge    1.00e-03
# 2               AgeGroup    1.00e-03
# 13         UnlimitedData    0.00e+00
# 1                    Age    0.00e+00
# 12           TechSupport    0.00e+00
# 11          OnlineBackup    0.00e+00
# 18  TotalExtraDataCharge    0.00e+00
# 9          PaymentMethod    0.00e+00
# 20       TotalRoamCharge    0.00e+00
# 8       PaperlessBilling    0.00e+00
# 6              Referrals    0.00e+00
# 23           TotalCharge    0.00e+00
# 4             Dependents    0.00e+00
# 3                Married    0.00e+00
# 0                 Gender    0.00e+00

# %%
# 설명변수 중요도 그래프
# sort_values : 중요도가 높은 변수를 상위에 그림. 
df_importance.sort_values("Importance", ascending=True, inplace = True)
coordinates = range(len(df_importance))
plt.barh(y = coordinates, width = df_importance["Importance"])
plt.yticks(coordinates, df_importance["Feature"])
plt.xlabel("설명변수 중요도")
plt.ylabel("설명변수")
# Out:
# Text(0, 0.5, '설명변수')

# %%
# 평가
y_pred = tree_uncustomized.predict(df_test_x)
print("Accuracy: {0:.3f}\n".format(tree_uncustomized.score(df_test_x, df_test_y)))
print("Confusion matrix: \n{}".format(confusion_matrix(df_test_y, y_pred)))

# 목표변수의 빈도 불균형 : f1 score로 모델 평가 
print(classification_report(df_test_y, y_pred, digits=3))
# Out:
# Accuracy: 0.989
#
# Confusion matrix:
# [[1524   11]
#  [  12  512]]
#               precision    recall  f1-score   support
#
#            0      0.992     0.993     0.993      1535
#            1      0.979     0.977     0.978       524
#
#     accuracy                          0.989      2059
#    macro avg      0.986     0.985     0.985      2059
# weighted avg      0.989     0.989     0.989      2059

# %%
# tree_final.dot으로 결과 저장
export_graphviz(tree_uncustomized, out_file="tree_uncustomized.dot", class_names = ["유지", "이탈"],
# export_graphviz(tree_final, out_file="tree_final.dot", 
                feature_names = v_feature_name, impurity = True, filled = True)
# tree_final.dot 그리기
with open("tree_uncustomized.dot") as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %%
pip install pydot
# Out:
# Requirement already satisfied: pydot in /Users/jay/.pyenv/versions/3.9.9/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /Users/jay/.pyenv/versions/3.9.9/lib/python3.9/site-packages (from pydot) (3.0.7)
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/jay/.pyenv/versions/3.9.9/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
with open('tree_uncustomized.dot') as file_reader:
    dot_graph = file_reader.read()

dot = graphviz.Source(dot_graph) # dot_graph의 source 저장

dot.render(filename='tree.png') # png로 저장
# Out:
# 'tree.png.pdf'

# %% [markdown]
# # 로지스틱회귀

# %%
df_raw[df_raw['ChurnLabel']==0]
# Out:
#       Gender  Age  AgeGroup  Married  Dependents  noDependents  Referrals  \
# 0          1   37        30        1           0             0          1
# 1          0   46        40        0           0             0          0
# 5          1   23        20        0           1             1          0
# 6          1   67        60        1           0             0          1
# 7          0   52        50        1           0             0          1
# ...      ...  ...       ...      ...         ...           ...        ...
# 6855       1   20        20        0           0             0          0
# 6858       1   20        20        0           0             0          0
# 6860       0   22        20        0           0             0          0
# 6861       0   21        20        0           0             0          1
# 6862       0   36        30        1           0             0          1
#
#       noReferrals  PaperlessBilling  PaymentMethod  ...  SatisScore  \
# 0               2                 1              1  ...           3
# 1               0                 0              1  ...           5
# 5               0                 1              1  ...           3
# 6               1                 1              0  ...           3
# 7               8                 1              1  ...           4
# ...           ...               ...            ...  ...         ...
# 6855            0                 1              1  ...           3
# 6858            0                 0              1  ...           4
# 6860            0                 1              1  ...           5
# 6861            5                 0              1  ...           3
# 6862            1                 0              0  ...           3
#
#       TotalExtraDataCharge  AvgRoamCharge  TotalRoamCharge  TenureMonths  \
# 0                        0          47910           431100            21
# 1                    11300          12090           108710            21
# 5                        0          18980           170520            21
# 6                        0          11300           799140            83
# 7                    22600          14690           922650            75
# ...                    ...            ...              ...           ...
# 6855                     0          41250           288600            19
# 6858                     0          52770           685680            25
# 6860                     0          21020            42040            14
# 6861                     0           2370           160460            79
# 6862                     0              0                0            75
#
#       AvgCharge  TotalCharge  TotalRevenue  MonthRoamCharge  \
# 0      83590.48      1755400       2186500            20528
# 1      68928.57      1447500       1567510             5176
# 5      81852.38      1718900       1889420             8120
# 6     129451.81     10744500      11543640             9628
# 7      99408.00      7455600       8400850            12302
# ...         ...          ...           ...              ...
# 6855  105905.26      2012200       2300800            15189
# 6858   64428.00      1610700       2296380            27427
# 6860   56600.00       792400        834440             3002
# 6861   80107.59      6328500       6488960             2031
# 6862   69281.33      5196100       5196100                0
#
#       AvgExtraDataCharge
# 0                      0
# 1                    538
# 5                      0
# 6                      0
# 7                    301
# ...                  ...
# 6855                   0
# 6858                   0
# 6860                   0
# 6861                   0
# 6862                   0
#
# [5161 rows x 28 columns]

# %% [markdown]
# ## 로지스틱 회귀모델 및 회귀계수 검토

# %%
s_df = df_raw

# %%
s_df
# Out:
#       Gender  Age  AgeGroup  Married  Dependents  noDependents  Referrals  \
# 0          1   37        30        1           0             0          1
# 1          0   46        40        0           0             0          0
# 2          0   50        50        0           0             0          0
# 3          0   78        70        1           0             0          1
# 4          1   75        70        1           0             0          1
# ...      ...  ...       ...      ...         ...           ...        ...
# 6858       1   20        20        0           0             0          0
# 6859       0   40        40        1           0             0          1
# 6860       0   22        20        0           0             0          0
# 6861       0   21        20        0           0             0          1
# 6862       0   36        30        1           0             0          1
#
#       noReferrals  PaperlessBilling  PaymentMethod  ...  SatisScore  \
# 0               2                 1              1  ...           3
# 1               0                 0              1  ...           5
# 2               0                 1              0  ...           1
# 3               1                 1              0  ...           1
# 4               3                 1              1  ...           1
# ...           ...               ...            ...  ...         ...
# 6858            0                 0              1  ...           4
# 6859            1                 1              0  ...           1
# 6860            0                 1              1  ...           5
# 6861            5                 0              1  ...           3
# 6862            1                 0              0  ...           3
#
#       TotalExtraDataCharge  AvgRoamCharge  TotalRoamCharge  TenureMonths  \
# 0                        0          47910           431100            21
# 1                    11300          12090           108710            21
# 2                        0          38080           152100             4
# 3                        0          31410           408720            13
# 4                        0           8360            24970             3
# ...                    ...            ...              ...           ...
# 6858                     0          52770           685680            25
# 6859                     0          18310           402730            22
# 6860                     0          21020            42040            14
# 6861                     0           2370           160460            79
# 6862                     0              0                0            75
#
#       AvgCharge  TotalCharge  TotalRevenue  MonthRoamCharge  \
# 0      83590.48      1755400       2186500            20528
# 1      68928.57      1447500       1567510             5176
# 2      98180.00       490900        643000            38025
# 3     112742.86      1578400       1987120            31440
# 4      94500.00       378000        402970             8323
# ...         ...          ...           ...              ...
# 6858   64428.00      1610700       2296380            27427
# 6859  101891.30      2343500       2746230            18305
# 6860   56600.00       792400        834440             3002
# 6861   80107.59      6328500       6488960             2031
# 6862   69281.33      5196100       5196100                0
#
#       AvgExtraDataCharge
# 0                      0
# 1                    538
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 6858                   0
# 6859                   0
# 6860                   0
# 6861                   0
# 6862                   0
#
# [6863 rows x 28 columns]

# %%
s_df.drop(['CustomerId', 'StartDate', 'EndDate',
             'EndDateTmp', 'ChurnCategory', 'ChurnReason'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [33], in <module>
# ----> 1 s_df.drop(['CustomerId', 'StartDate', 'EndDate',
#       2              'EndDateTmp', 'ChurnCategory', 'ChurnReason'], axis=1, inplace=True)
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/pandas/core/frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
#    4802     self,
#    (...)
#    4809     errors: str = "raise",
#    4810 ):
#    4811     """
#    4812     Drop specified labels from rows or columns.
#    4813
#    (...)
#    4946             weight  1.0     0.8
#    4947     """
# -> 4948     return super().drop(
#    4949         labels=labels,
#    4950         axis=axis,
#    4951         index=index,
#    4952         columns=columns,
#    4953         level=level,
#    4954         inplace=inplace,
#    4955         errors=errors,
#    4956     )
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/pandas/core/generic.py:4279, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4277 for axis, labels in axes.items():
#    4278     if labels is not None:
# -> 4279         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4281 if inplace:
#    4282     self._update_inplace(obj)
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/pandas/core/generic.py:4323, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4321         new_axis = axis.drop(labels, level=level, errors=errors)
#    4322     else:
# -> 4323         new_axis = axis.drop(labels, errors=errors)
#    4324     indexer = axis.get_indexer(new_axis)
#    4326 # Case for non-unique axis
#    4327 else:
#
# File ~/.pyenv/versions/3.9.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['CustomerId', 'StartDate', 'EndDate', 'EndDateTmp', 'ChurnCategory', 'ChurnReason'] not found in axis"

# %%
# 변수명 저장
v_feature_names = s_df.columns
# StandardScaler 적용
scaler = StandardScaler()
df_scaled = scaler.fit_transform(s_df)
df_scaled = pd.DataFrame(df_scaled, columns=v_feature_names)
df_scaled.head()

# %%
df_scaled.info()

# %%
df_y = df_raw['ChurnLabel']

# %%
ss_df = pd.concat([df_y, df_scaled], axis=1)
ss_df
# Out:
#       ChurnLabel  Gender   Age  AgeGroup  Married  Dependents  noDependents  \
# 0              0    1.01 -0.58     -0.74     1.15       -0.52         -0.47
# 1              0   -0.99 -0.04     -0.14    -0.87       -0.52         -0.47
# 2              1   -0.99  0.20      0.47    -0.87       -0.52         -0.47
# 3              1   -0.99  1.89      1.68     1.15       -0.52         -0.47
# 4              1    1.01  1.71      1.68     1.15       -0.52         -0.47
# ...          ...     ...   ...       ...      ...         ...           ...
# 6858           0    1.01 -1.60     -1.35    -0.87       -0.52         -0.47
# 6859           1   -0.99 -0.40     -0.14     1.15       -0.52         -0.47
# 6860           0   -0.99 -1.48     -1.35    -0.87       -0.52         -0.47
# 6861           0   -0.99 -1.54     -1.35    -0.87       -0.52         -0.47
# 6862           0   -0.99 -0.64     -0.74     1.15       -0.52         -0.47
#
#       Referrals  noReferrals  PaperlessBilling  ...  SatisScore  \
# 0          1.08     3.08e-03              0.83  ...       -0.23
# 1         -0.93    -6.58e-01             -1.20  ...        1.45
# 2         -0.93    -6.58e-01              0.83  ...       -1.92
# 3          1.08    -3.28e-01              0.83  ...       -1.92
# 4          1.08     3.34e-01              0.83  ...       -1.92
# ...         ...          ...               ...  ...         ...
# 6858      -0.93    -6.58e-01             -1.20  ...        0.61
# 6859       1.08    -3.28e-01              0.83  ...       -1.92
# 6860      -0.93    -6.58e-01              0.83  ...        1.45
# 6861       1.08     9.95e-01             -1.20  ...       -0.23
# 6862       1.08    -3.28e-01             -1.20  ...       -0.23
#
#       TotalExtraDataCharge  AvgRoamCharge  TotalRoamCharge  TenureMonths  \
# 0                    -0.28           1.26            -0.45         -0.80
# 1                     0.12          -0.79            -0.79         -0.80
# 2                    -0.28           0.69            -0.75         -1.44
# 3                    -0.28           0.31            -0.48         -1.10
# 4                    -0.28          -1.01            -0.88         -1.48
# ...                    ...            ...              ...           ...
# 6858                 -0.28           1.53            -0.19         -0.65
# 6859                 -0.28          -0.44            -0.48         -0.76
# 6860                 -0.28          -0.28            -0.86         -1.07
# 6861                 -0.28          -1.35            -0.74          1.39
# 6862                 -0.28          -1.49            -0.90          1.24
#
#       AvgCharge  TotalCharge  TotalRevenue  MonthRoamCharge  \
# 0          0.20        -0.55         -0.58             0.08
# 1         -0.21        -0.66         -0.75            -0.94
# 2          0.61        -0.97         -1.00             1.23
# 3          1.02        -0.61         -0.63             0.80
# 4          0.51        -1.01         -1.06            -0.73
# ...         ...          ...           ...              ...
# 6858      -0.34        -0.60         -0.55             0.53
# 6859       0.72        -0.36         -0.42            -0.07
# 6860      -0.56        -0.87         -0.95            -1.08
# 6861       0.10         0.97          0.60            -1.14
# 6862      -0.20         0.59          0.25            -1.28
#
#       AvgExtraDataCharge
# 0                  -0.15
# 1                   0.08
# 2                  -0.15
# 3                  -0.15
# 4                  -0.15
# ...                  ...
# 6858               -0.15
# 6859               -0.15
# 6860               -0.15
# 6861               -0.15
# 6862               -0.15
#
# [6863 rows x 29 columns]

# %%
ss_df.to_csv('ss_SCALE.csv')

# %%
df = pd.read_csv('ss_SCALE.csv', encoding='euc-kr')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#       ChurnLabel  Gender   Age  AgeGroup  Married  Dependents  noDependents  \
# 0              0    1.01 -0.58     -0.74     1.15       -0.52         -0.47
# 1              0   -0.99 -0.04     -0.14    -0.87       -0.52         -0.47
# 2              1   -0.99  0.20      0.47    -0.87       -0.52         -0.47
# 3              1   -0.99  1.89      1.68     1.15       -0.52         -0.47
# 4              1    1.01  1.71      1.68     1.15       -0.52         -0.47
# ...          ...     ...   ...       ...      ...         ...           ...
# 6858           0    1.01 -1.60     -1.35    -0.87       -0.52         -0.47
# 6859           1   -0.99 -0.40     -0.14     1.15       -0.52         -0.47
# 6860           0   -0.99 -1.48     -1.35    -0.87       -0.52         -0.47
# 6861           0   -0.99 -1.54     -1.35    -0.87       -0.52         -0.47
# 6862           0   -0.99 -0.64     -0.74     1.15       -0.52         -0.47
#
#       Referrals  noReferrals  PaperlessBilling  ...  SatisScore  \
# 0          1.08     3.08e-03              0.83  ...       -0.23
# 1         -0.93    -6.58e-01             -1.20  ...        1.45
# 2         -0.93    -6.58e-01              0.83  ...       -1.92
# 3          1.08    -3.28e-01              0.83  ...       -1.92
# 4          1.08     3.34e-01              0.83  ...       -1.92
# ...         ...          ...               ...  ...         ...
# 6858      -0.93    -6.58e-01             -1.20  ...        0.61
# 6859       1.08    -3.28e-01              0.83  ...       -1.92
# 6860      -0.93    -6.58e-01              0.83  ...        1.45
# 6861       1.08     9.95e-01             -1.20  ...       -0.23
# 6862       1.08    -3.28e-01             -1.20  ...       -0.23
#
#       TotalExtraDataCharge  AvgRoamCharge  TotalRoamCharge  TenureMonths  \
# 0                    -0.28           1.26            -0.45         -0.80
# 1                     0.12          -0.79            -0.79         -0.80
# 2                    -0.28           0.69            -0.75         -1.44
# 3                    -0.28           0.31            -0.48         -1.10
# 4                    -0.28          -1.01            -0.88         -1.48
# ...                    ...            ...              ...           ...
# 6858                 -0.28           1.53            -0.19         -0.65
# 6859                 -0.28          -0.44            -0.48         -0.76
# 6860                 -0.28          -0.28            -0.86         -1.07
# 6861                 -0.28          -1.35            -0.74          1.39
# 6862                 -0.28          -1.49            -0.90          1.24
#
#       AvgCharge  TotalCharge  TotalRevenue  MonthRoamCharge  \
# 0          0.20        -0.55         -0.58             0.08
# 1         -0.21        -0.66         -0.75            -0.94
# 2          0.61        -0.97         -1.00             1.23
# 3          1.02        -0.61         -0.63             0.80
# 4          0.51        -1.01         -1.06            -0.73
# ...         ...          ...           ...              ...
# 6858      -0.34        -0.60         -0.55             0.53
# 6859       0.72        -0.36         -0.42            -0.07
# 6860      -0.56        -0.87         -0.95            -1.08
# 6861       0.10         0.97          0.60            -1.14
# 6862      -0.20         0.59          0.25            -1.28
#
#       AvgExtraDataCharge
# 0                  -0.15
# 1                   0.08
# 2                  -0.15
# 3                  -0.15
# 4                  -0.15
# ...                  ...
# 6858               -0.15
# 6859               -0.15
# 6860               -0.15
# 6861               -0.15
# 6862               -0.15
#
# [6863 rows x 29 columns]

# %%
# train_test_split(데이터, test_size = test 데이터 비율, random_state: 랜덤)
df_train, df_test = train_test_split(df, # 데이터
                                     test_size = 0.3, # test 데이터의 비율
                                     random_state = 42)  # random state

print("train data size : {}".format(df_train.shape))
print("test data size : {}".format(df_test.shape))
# Out:
# train data size : (4804, 29)
# test data size : (2059, 29)

# %%
df_train
# Out:
#       ChurnLabel  Gender   Age  AgeGroup  Married  Dependents  noDependents  \
# 4899           1    1.01  1.71      1.68    -0.87       -0.52         -0.47
# 4074           0    1.01  0.02     -0.14     1.15       -0.52         -0.47
# 1112           0    1.01  0.45      0.47    -0.87       -0.52         -0.47
# 776            0    1.01  1.11      1.08     1.15       -0.52         -0.47
# 6484           0   -0.99  1.35      1.08     1.15       -0.52         -0.47
# ...          ...     ...   ...       ...      ...         ...           ...
# 3772           1   -0.99 -0.76     -0.74     1.15       -0.52         -0.47
# 5191           1    1.01 -1.24     -1.35    -0.87       -0.52         -0.47
# 5226           0   -0.99  0.14     -0.14    -0.87       -0.52         -0.47
# 5390           0    1.01 -0.76     -0.74    -0.87       -0.52         -0.47
# 860            1   -0.99  0.93      1.08    -0.87        1.93          2.94
#
#       Referrals  noReferrals  PaperlessBilling  ...  SatisScore  \
# 4899      -0.93        -0.66              0.83  ...       -1.92
# 4074       1.08         2.32             -1.20  ...        0.61
# 1112      -0.93        -0.66              0.83  ...       -0.23
# 776        1.08         1.66              0.83  ...        1.45
# 6484       1.08         2.65              0.83  ...       -0.23
# ...         ...          ...               ...  ...         ...
# 3772       1.08        -0.33             -1.20  ...       -0.23
# 5191      -0.93        -0.66              0.83  ...       -1.08
# 5226      -0.93        -0.66              0.83  ...        1.45
# 5390      -0.93        -0.66             -1.20  ...       -0.23
# 860       -0.93        -0.66             -1.20  ...       -1.08
#
#       TotalExtraDataCharge  AvgRoamCharge  TotalRoamCharge  TenureMonths  \
# 4899                 -0.28           1.22            -0.76         -1.48
# 4074                 -0.28           0.14             0.54          0.71
# 1112                 -0.28          -1.30            -0.77          0.37
# 776                  -0.28           1.74             3.03          1.39
# 6484                 -0.28          -0.75             0.04          1.54
# ...                    ...            ...              ...           ...
# 3772                 -0.28           0.32            -0.28         -0.88
# 5191                 -0.28          -0.34            -0.11         -0.16
# 5226                 -0.28          -0.41            -0.88         -1.10
# 5390                 -0.28           0.68            -0.59         -0.84
# 860                  -0.28           0.01            -0.88         -1.56
#
#       AvgCharge  TotalCharge  TotalRevenue  MonthRoamCharge  \
# 4899       0.34        -1.02         -1.04             1.85
# 4074       0.21         0.56          0.60             0.22
# 1112       0.92         0.75          0.41            -1.12
# 776       -1.48        -0.51          0.37             1.88
# 6484       0.16         1.13          0.94            -0.55
# ...         ...          ...           ...              ...
# 3772       1.25        -0.33         -0.35             0.81
# 5191       0.67         0.16          0.10             0.04
# 5226       0.74        -0.69         -0.80            -1.18
# 5390       0.02        -0.62         -0.67            -0.28
# 860        0.55        -1.07         -1.12             0.45
#
#       AvgExtraDataCharge
# 4899               -0.15
# 4074               -0.15
# 1112               -0.15
# 776                -0.15
# 6484               -0.15
# ...                  ...
# 3772               -0.15
# 5191               -0.15
# 5226               -0.15
# 5390               -0.15
# 860                -0.15
#
# [4804 rows x 29 columns]

# %% [markdown]
# ## 로지스틱 회귀모델 및 회귀계수 검토

# %%
df
# Out:
#       ChurnLabel  Gender   Age  AgeGroup  Married  Dependents  noDependents  \
# 0              0    1.01 -0.58     -0.74     1.15       -0.52         -0.47
# 1              0   -0.99 -0.04     -0.14    -0.87       -0.52         -0.47
# 2              1   -0.99  0.20      0.47    -0.87       -0.52         -0.47
# 3              1   -0.99  1.89      1.68     1.15       -0.52         -0.47
# 4              1    1.01  1.71      1.68     1.15       -0.52         -0.47
# ...          ...     ...   ...       ...      ...         ...           ...
# 6858           0    1.01 -1.60     -1.35    -0.87       -0.52         -0.47
# 6859           1   -0.99 -0.40     -0.14     1.15       -0.52         -0.47
# 6860           0   -0.99 -1.48     -1.35    -0.87       -0.52         -0.47
# 6861           0   -0.99 -1.54     -1.35    -0.87       -0.52         -0.47
# 6862           0   -0.99 -0.64     -0.74     1.15       -0.52         -0.47
#
#       Referrals  noReferrals  PaperlessBilling  ...  SatisScore  \
# 0          1.08     3.08e-03              0.83  ...       -0.23
# 1         -0.93    -6.58e-01             -1.20  ...        1.45
# 2         -0.93    -6.58e-01              0.83  ...       -1.92
# 3          1.08    -3.28e-01              0.83  ...       -1.92
# 4          1.08     3.34e-01              0.83  ...       -1.92
# ...         ...          ...               ...  ...         ...
# 6858      -0.93    -6.58e-01             -1.20  ...        0.61
# 6859       1.08    -3.28e-01              0.83  ...       -1.92
# 6860      -0.93    -6.58e-01              0.83  ...        1.45
# 6861       1.08     9.95e-01             -1.20  ...       -0.23
# 6862       1.08    -3.28e-01             -1.20  ...       -0.23
#
#       TotalExtraDataCharge  AvgRoamCharge  TotalRoamCharge  TenureMonths  \
# 0                    -0.28           1.26            -0.45         -0.80
# 1                     0.12          -0.79            -0.79         -0.80
# 2                    -0.28           0.69            -0.75         -1.44
# 3                    -0.28           0.31            -0.48         -1.10
# 4                    -0.28          -1.01            -0.88         -1.48
# ...                    ...            ...              ...           ...
# 6858                 -0.28           1.53            -0.19         -0.65
# 6859                 -0.28          -0.44            -0.48         -0.76
# 6860                 -0.28          -0.28            -0.86         -1.07
# 6861                 -0.28          -1.35            -0.74          1.39
# 6862                 -0.28          -1.49            -0.90          1.24
#
#       AvgCharge  TotalCharge  TotalRevenue  MonthRoamCharge  \
# 0          0.20        -0.55         -0.58             0.08
# 1         -0.21        -0.66         -0.75            -0.94
# 2          0.61        -0.97         -1.00             1.23
# 3          1.02        -0.61         -0.63             0.80
# 4          0.51        -1.01         -1.06            -0.73
# ...         ...          ...           ...              ...
# 6858      -0.34        -0.60         -0.55             0.53
# 6859       0.72        -0.36         -0.42            -0.07
# 6860      -0.56        -0.87         -0.95            -1.08
# 6861       0.10         0.97          0.60            -1.14
# 6862      -0.20         0.59          0.25            -1.28
#
#       AvgExtraDataCharge
# 0                  -0.15
# 1                   0.08
# 2                  -0.15
# 3                  -0.15
# 4                  -0.15
# ...                  ...
# 6858               -0.15
# 6859               -0.15
# 6860               -0.15
# 6861               -0.15
# 6862               -0.15
#
# [6863 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['ChurnLabel', 'Gender', 'Age', 'AgeGroup', 'Married', 'Dependents',
#        'noDependents', 'Referrals', 'noReferrals', 'PaperlessBilling',
#        'PaymentMethod', 'OnlineSecurity', 'OnlineBackup', 'TechSupport',
#        'UnlimitedData', 'AvgDownloadGB', 'ChurnLabel.1', 'ChurnScore',
#        'CustomerLTV', 'SatisScore', 'TotalExtraDataCharge', 'AvgRoamCharge',
#        'TotalRoamCharge', 'TenureMonths', 'AvgCharge', 'TotalCharge',
#        'TotalRevenue', 'MonthRoamCharge', 'AvgExtraDataCharge'],
#       dtype='object')

# %%
# from_formula 함수를 이용하여 변수 역할 지정
# 분석 대상 이벤트=“1”
log_model = Logit.from_formula('ChurnLabel ~ Gender + Age + C(AgeGroup) + C(Married) + Dependents + noDependents + Referrals + noReferrals \n
                                + PaperlessBilling + PaymentMethod + OnlineSecurity + OnlineBackup + TechSupport \n
                                + UnlimitedData + AvgDownloadGB + ChurnScore + CustomerLTV + SatisScore + TotalExtraDataCharge \n
                                + AvgRoamCharge + TotalRoamCharge + TenureMonths + AvgCharge + TotalCharge + TotalRevenue + MonthRoamCharge + AvgExtraDataCharge', df_train)
# 적합
log_result = log_model.fit()

# 결과 출력
print(log_result.summary())
# Out:
#   Input In [43]
#     log_model = Logit.from_formula('ChurnLabel ~ Gender + Age + AgeGroup + Married + Dependents + noDependents + Referrals + noReferrals \n
#                                                                                                                                            ^
# SyntaxError: EOL while scanning string literal
